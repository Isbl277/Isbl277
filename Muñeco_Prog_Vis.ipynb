# %% [markdown]
# <a href="https://colab.research.google.com/github/Isbl277/Isbl277/blob/main/Mu%C3%B1eco_Prog_Vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# Crear un lienzo en blanco
img = np.zeros((512, 512, 3), np.uint8)

# %%
img = cv2.circle (img, (240,63), 60, (255,255,255), 2, cv2.LINE_AA)



img = cv2.line (img, (210,30), (190,50), (255,255,255), 2)
img = cv2.line (img, (210,30), (240,60), (255,255,255), 2)
img = cv2.line (img, (240,60), (270,30), (255,255,255), 2)
img = cv2.line (img, (290,50), (270,30), (255,255,255), 2)

img = cv2.line(img, (220, 80), (260, 80), (255, 255, 255), 2)


img = cv2.line(img, (300, 400), (340, 450), (255, 255, 255), 2)
img = cv2.line(img, (280, 440), (340, 450), (255, 255, 255), 2)
img = cv2.line(img, (300, 400), (280, 440), (255, 255, 255), 2)


img = cv2.line(img, (160, 450), (200, 400), (255, 255, 255), 2)
img = cv2.line(img, (160, 450), (220, 440), (255, 255, 255), 2)
img = cv2.line(img, (200, 400), (220, 440), (255, 255, 255), 2)

plt.imshow (cv2.cvtColor (img, cv2.COLOR_BGR2RGB));

# %%
img = cv2.circle (img, (240,63), 60, (255,255,255), 2)

img = cv2.line(img, (220, 80), (260, 80), (255, 255, 255), 5)

# Mostrar la imagen
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img = cv2.circle (img, (240,63), 60, (255,255,255), 2)

img = cv2.line(img, (220, 80), (260, 80), (255, 255, 255), 5)

img = cv2.line(img, (130, 120), (350, 120), (225, 225, 245), 2)  # Hombros
img = cv2.line(img, (128, 120), (180, 240), (255, 255, 255), 2)  # Lado izq torso
img = cv2.line(img, (350, 120), (300, 240), (255, 255, 255), 2)  # Lado der torso
img = cv2.line(img, (180, 240), (300, 240), (255, 255, 255), 2)  # Cintura

# Mostrar la imagen
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img = cv2.circle (img, (240,63), 60, (255,255,255), 2)

img = cv2.line(img, (220, 80), (260, 80), (255, 255, 255), 5)
#hombros y cintura
img = cv2.line(img, (130, 120), (350, 120), (225, 225, 245), 2)
img = cv2.line(img, (128, 120), (180, 240), (255, 255, 255), 2)
img = cv2.line(img, (350, 120), (300, 240), (255, 255, 255), 2)
img = cv2.line(img, (180, 240), (300, 240), (255, 255, 255), 2)
#brazos izq y der
img = cv2.line(img, (100, 200), (127, 120), (255, 255, 255), 2)
img = cv2.line(img, (350, 120), (377, 200), (255, 255, 255), 2)

# Mostrar la imagen
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img = cv2.circle (img, (240,63), 60, (255,255,255), 2)

img = cv2.line(img, (220, 80), (260, 80), (255, 255, 255), 5)
#hombros y cintura
img = cv2.line(img, (130, 120), (350, 120), (225, 225, 245), 2)
img = cv2.line(img, (128, 120), (180, 240), (255, 255, 255), 2)
img = cv2.line(img, (350, 120), (300, 240), (255, 255, 255), 2)
img = cv2.line(img, (180, 240), (300, 240), (255, 255, 255), 2)
#brazos izq y der
cv2.line(img, (58, 165), (70, 100), (255, 255, 255), 2)
cv2.line(img, (70, 100), (99,200), (255, 255, 255), 2)
cv2.line(img, (60, 165), (90, 165), (255, 255, 255), 2)

cv2.line(img, (377, 200), (390, 100), (255, 255, 255), 2)
cv2.line(img, (390, 100), (410, 160), (255, 255, 255), 2)
cv2.line(img, (380, 160), (410, 160), (255, 255, 255), 2)

# Mostrar la imagen
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
